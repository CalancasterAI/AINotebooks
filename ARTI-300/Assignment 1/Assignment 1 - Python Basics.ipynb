# %% [markdown]
# ## Assignment 1

# %%
# create variable and set its value to "Assignment 1 - Python basics" and display the variable value

# %%
# check the type of the variable you just created

# %%
# check to see if the variable value is all caps

# %%
# create another variable and assign 25 to it and display the variable value

# %%
# check the type of the variable

# %%
# update that variables value to its current value divided by 6 and display the variable value

# %%
# check the type of the variable again

# %%
# create another variable and assign the string "25" to it and display the variable value

# %%
# check the type of the variable

# %%
# convert the variable to type int and display the variable value

# %%
# verify that the variable is of type int

# %%
# create a list with the following values - 3, 5, 2.1 "lists are fun", 4.6, "35" and display the list

# %%
# change the value 2.1 to 21.21 and display the list

# %%
# add another value to the end of the list, remove 4.6 from the list, and display the list

# %%
# write a for loop  for i = 3 to 10 that displays i*10 for each iteration - output should include 100

# %%
# write a while loop produces the same results as the for loop

# %%
# create user defined function that accepts 3 inputs - a, b, operationtype.  Operationtype values can include 
# add, subtract or multiple.  Based on the value of operationtype displays a+b, a-b, or a*b. Call the function at 
# least 3 times with different inputs

# %%
# create a lambda function that accepts to inputs a, b and cals a*b-b. Call the function at least 3 times with
# different inputs

# %%
# open the Halloween.csv file found in Canvas

# %%
# find how many rows and columns there are in the dataset - include the number of rows and columns in a comment

# %%
# what are names of the columns and datatypes of each column - include the answer in a markdown cell

# %%
# what are the uniques values in the DayOfWeek column?

# %%
# what is the mean value of the Count column?
